# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#import my dataset
data_file = pd.read_csv('Sleep_health_and_lifestyle_dataset.csv', header=0)
data_file.drop_duplicates()
data_file
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
data_file.describe().T
# Out:
#                          count         mean          std     min      25%  \
# Person ID                374.0   187.500000   108.108742     1.0    94.25
# Age                      374.0    42.184492     8.673133    27.0    35.25
# Sleep Duration           374.0     7.132086     0.795657     5.8     6.40
# Quality of Sleep         374.0     7.312834     1.196956     4.0     6.00
# Physical Activity Level  374.0    59.171123    20.830804    30.0    45.00
# Stress Level             374.0     5.385027     1.774526     3.0     4.00
# Heart Rate               374.0    70.165775     4.135676    65.0    68.00
# Daily Steps              374.0  6816.844920  1617.915679  3000.0  5600.00
#
#                             50%      75%      max
# Person ID                 187.5   280.75    374.0
# Age                        43.0    50.00     59.0
# Sleep Duration              7.2     7.80      8.5
# Quality of Sleep            7.0     8.00      9.0
# ...

# %%
data_file.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
data_file.tail()
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 369        370  Female   59      Nurse             8.1                 9
# 370        371  Female   59      Nurse             8.0                 9
# 371        372  Female   59      Nurse             8.1                 9
# 372        373  Female   59      Nurse             8.1                 9
# 373        374  Female   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 369                       75             3   Overweight         140/95
# 370                       75             3   Overweight         140/95
# 371                       75             3   Overweight         140/95
# 372                       75             3   Overweight         140/95
# 373                       75             3   Overweight         140/95
#
#      Heart Rate  Daily Steps Sleep Disorder
# 369          68         7000    Sleep Apnea
# ...

# %%
histogram = data_file.hist(bins=10, figsize=(10,10))

# %%
data_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
# Selecting columns of type 'object' (categorical columns)
df_cat = data_file.select_dtypes(include='object').copy()

# Counting the occurrences of each unique value in each column
value_counts = df_cat.apply(lambda x: x.value_counts())

# Plotting the count of occurrences for the 'Sleep Disorder' column
sns.countplot(data=df_cat, x='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# Selecting columns of type 'object' (categorical columns)
df_cat = data_file.select_dtypes(include='object').copy()

# Counting the occurrences of each unique value in each column
value_counts = df_cat.apply(lambda x: x.value_counts())

# Plotting the count of occurrences for the 'Sleep Disorder' column
sns.countplot(data=df_cat, x='Occupation')
plt.xticks(rotation=90)
plt.show()

# %%
# Selecting columns of type 'object' (categorical columns)
df_cat = data_file.select_dtypes(include='object').copy()

# Counting the occurrences of each unique value in each column
value_counts = df_cat.apply(lambda x: x.value_counts())

# Plotting the count of occurrences for the 'Sleep Disorder' column
sns.countplot(data=df_cat, x='BMI Category')
# Out:
# <Axes: xlabel='BMI Category', ylabel='count'>

# %%
# Selecting columns of type 'object' (categorical columns)
df_cat = data_file.select_dtypes(include='object').copy()

# Counting the occurrences of each unique value in each column
value_counts = df_cat.apply(lambda x: x.value_counts())

# Plotting the count of occurrences for the 'Sleep Disorder' column
sns.countplot(data=df_cat, x='Sleep Disorder')
# Out:
# <Axes: xlabel='Sleep Disorder', ylabel='count'>

# %%
#create a boxplot for every column in df
boxplot = data_file.boxplot(grid=False, vert=False,fontsize=15)
